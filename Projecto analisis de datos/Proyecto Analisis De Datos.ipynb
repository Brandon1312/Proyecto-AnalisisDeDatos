# %% [markdown]
# <h5 Style= 'color:#69d0b3'> Brandon Retana Diaz</h5>
# <h5 Style= 'color:#69d0b3'> Grupo #1 Analisis de Datos</h5>
# <h5 Style= 'color:#69d0b3'> Universidad Castro Carazo</h5>
#
#
#
#
# <img src="img04.png" width="200" >
#
# <h1  Style='text-align:center; color:#2790b0'> Proyecto De Analisis De Datos</h1>
# <br></br>
# <br></br>
#
# <h3 Style= 'text-align:center; color:#233f65'> DataSet de Bienes y Raíces</h3>
# <br></br>
# <br></br>
# <h4 Style= 'color:#4a50a7'>Importando las librerias.</h4>

# %%
import pandas as pd #Se usa para el dataFrame
import numpy as np # Se usa para el manejo de estructuras de datos
import matplotlib.pyplot as plt #Se usa para crear graficos

# %%
df_BienesRaices = pd.read_excel("BienesRaices.xlsx", sheet_name='DataSet' )

# %%
df_BienesRaices.shape
# Out:
# (199258, 12)

# %%
df_BienesRaices.head(5)
# Out:
#    Serial Number  List Year     Town                Address  Assessed Value  \
# 0          20002       2020  Ashford        390 TURNPIKE RD        253000.0
# 1         200212       2020     Avon       5 CHESTNUT DRIVE        130400.0
# 2         200243       2020     Avon  111 NORTHINGTON DRIVE        619290.0
# 3         200377       2020     Avon     70 FAR HILLS DRIVE        862330.0
# 4         200109       2020     Avon     57 FAR HILLS DRIVE        847520.0
#
#    Sale Amount  Sales Ratio Property Type Residential Type Non Use Code  \
# 0     430000.0       0.5883   Residential    Single Family          NaN
# 1     179900.0       0.7248   Residential            Condo          NaN
# 2     890000.0       0.6958   Residential    Single Family          NaN
# 3    1447500.0       0.5957   Residential    Single Family          NaN
# 4    1250000.0       0.6780   Residential    Single Family          NaN
#
#   Assessor Remarks OPM remarks
# 0              NaN         NaN
# ...

# %%
df_BienesRaices.tail(5)
# Out:
#         Serial Number  List Year           Town         Address  \
# 199253          20763       2002     West Haven    130 JONES ST
# 199254          21066       2002  West Hartford    15 PORTER DR
# 199255          30531       2003  East Hartford   43 TIFFANY RD
# 199256          30624       2003        Bristol   81 ANDREWS ST
# 199257          30434       2003      Greenwich  57 PROSPECT ST
#
#         Assessed Value  Sale Amount  Sales Ratio Property Type  \
# 199253         70700.0     179000.0     0.394972           NaN
# 199254        240880.0     515000.0     0.467728           NaN
# 199255         80330.0     130000.0     0.617923           NaN
# 199256         69230.0     130000.0     0.532538           NaN
# 199257        183470.0     375000.0     0.489253           NaN
#
#        Residential Type Non Use Code Assessor Remarks OPM remarks
# 199253              NaN          NaN              NaN         NaN
# 199254              NaN          NaN              NaN         NaN
# ...

# %%
df_BienesRaices.describe
# Out:
# <bound method NDFrame.describe of         Serial Number  List Year           Town                Address  \
# 0               20002       2020        Ashford        390 TURNPIKE RD
# 1              200212       2020           Avon       5 CHESTNUT DRIVE
# 2              200243       2020           Avon  111 NORTHINGTON DRIVE
# 3              200377       2020           Avon     70 FAR HILLS DRIVE
# 4              200109       2020           Avon     57 FAR HILLS DRIVE
# ...               ...        ...            ...                    ...
# 199253          20763       2002     West Haven           130 JONES ST
# 199254          21066       2002  West Hartford           15 PORTER DR
# 199255          30531       2003  East Hartford          43 TIFFANY RD
# 199256          30624       2003        Bristol          81 ANDREWS ST
# 199257          30434       2003      Greenwich         57 PROSPECT ST
#
#         Assessed Value  Sale Amount  Sales Ratio Property Type  \
# ...

# %%
df_BienesRaices.columns
# Out:
# Index(['Serial Number', 'List Year', 'Town', 'Address', 'Assessed Value',
#        'Sale Amount', 'Sales Ratio', 'Property Type', 'Residential Type',
#        'Non Use Code', 'Assessor Remarks', 'OPM remarks'],
#       dtype='object')

# %%
df_BienesRaices.rename({'Serial Number': 'serialNumber'},axis=1, inplace=True)
df_BienesRaices.rename({'List Year': 'listYear'},axis=1, inplace=True)
df_BienesRaices.rename({'Date Recorded': 'dateRecorded'},axis=1, inplace=True)
df_BienesRaices.rename({'Town': 'town'},axis=1, inplace=True)
df_BienesRaices.rename({'Assessed Value': 'assessedValue'},axis=1, inplace=True)
df_BienesRaices.rename({'Sale Amount': 'saleAmount'},axis=1, inplace=True)
df_BienesRaices.rename({'Sales Ratio': 'salesRatio'},axis=1, inplace=True)
df_BienesRaices.rename({'Property Type': 'propertyType'},axis=1, inplace=True)
df_BienesRaices.rename({'Residential Type': 'residentialType'},axis=1, inplace=True)
df_BienesRaices.rename({'Non Use Code': 'nonUseCode'},axis=1, inplace=True)
df_BienesRaices.rename({'Assessor Remarks': 'assessorRemarks'},axis=1, inplace=True)
df_BienesRaices.rename({'OPM remarks': 'oPMremarks'},axis=1, inplace=True)
df_BienesRaices.rename({'Location;;;;;': 'location'},axis=1, inplace=True)
df_BienesRaices.columns
# Out:
# Index(['serialNumber', 'listYear', 'town', 'Address', 'assessedValue',
#        'saleAmount', 'salesRatio', 'propertyType', 'residentialType',
#        'nonUseCode', 'assessorRemarks', 'oPMremarks'],
#       dtype='object')

# %%
df_BienesRaices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199258 entries, 0 to 199257
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   serialNumber     199258 non-null  int64
#  1   listYear         199258 non-null  int64
#  2   town             199258 non-null  object
#  3   Address          199251 non-null  object
#  4   assessedValue    199258 non-null  float64
#  5   saleAmount       199258 non-null  float64
#  6   salesRatio       199258 non-null  float64
#  7   propertyType     65892 non-null   object
#  8   residentialType  60262 non-null   object
#  9   nonUseCode       45092 non-null   object
#  10  assessorRemarks  13525 non-null   object
#  11  oPMremarks       1770 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 18.2+ MB

# %%
df_BienesRaices.replace(";;;;;", np.nan,inplace=True )
df_BienesRaices.head(5)
# Out:
#    serialNumber  listYear     town                Address  assessedValue  \
# 0         20002      2020  Ashford        390 TURNPIKE RD       253000.0
# 1        200212      2020     Avon       5 CHESTNUT DRIVE       130400.0
# 2        200243      2020     Avon  111 NORTHINGTON DRIVE       619290.0
# 3        200377      2020     Avon     70 FAR HILLS DRIVE       862330.0
# 4        200109      2020     Avon     57 FAR HILLS DRIVE       847520.0
#
#    saleAmount  salesRatio propertyType residentialType nonUseCode  \
# 0    430000.0      0.5883  Residential   Single Family        NaN
# 1    179900.0      0.7248  Residential           Condo        NaN
# 2    890000.0      0.6958  Residential   Single Family        NaN
# 3   1447500.0      0.5957  Residential   Single Family        NaN
# 4   1250000.0      0.6780  Residential   Single Family        NaN
#
#   assessorRemarks oPMremarks
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# ...

# %%
dfTemp= df_BienesRaices.isnull()
dfTemp.head(5)
# Out:
#    serialNumber  listYear   town  Address  assessedValue  saleAmount  \
# 0         False     False  False    False          False       False
# 1         False     False  False    False          False       False
# 2         False     False  False    False          False       False
# 3         False     False  False    False          False       False
# 4         False     False  False    False          False       False
#
#    salesRatio  propertyType  residentialType  nonUseCode  assessorRemarks  \
# 0       False         False            False        True             True
# 1       False         False            False        True             True
# 2       False         False            False        True             True
# 3       False         False            False        True             True
# 4       False         False            False        True             True
#
#    oPMremarks
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
for columna in dfTemp.columns.values.tolist():
    print(columna)
    print(dfTemp[columna].value_counts())
    print("")
# Out:
# serialNumber
# False    199258
# Name: serialNumber, dtype: int64
#
# listYear
# False    199258
# Name: listYear, dtype: int64
#
# town
# False    199258
# Name: town, dtype: int64
#
# Address
# False    199251
# True          7
# Name: Address, dtype: int64
#
# assessedValue
# False    199258
# Name: assessedValue, dtype: int64
#
# saleAmount
# False    199258
# Name: saleAmount, dtype: int64
#
# salesRatio
# False    199258
# Name: salesRatio, dtype: int64
#
# propertyType
# True     133366
# False     65892
# Name: propertyType, dtype: int64
#
# residentialType
# True     138996
# False     60262
# Name: residentialType, dtype: int64
#
# nonUseCode
# True     154166
# False     45092
# Name: nonUseCode, dtype: int64
#
# assessorRemarks
# True     185733
# False     13525
# Name: assessorRemarks, dtype: int64
#
# oPMremarks
# True     197488
# False      1770
# Name: oPMremarks, dtype: int64

# %%
dfTemp= df_BienesRaices.isnull()
for columna in dfTemp.columns.values.tolist():
    print(columna)
    print(dfTemp[columna].value_counts())
    print("")
# Out:
# serialNumber
# False    199258
# Name: serialNumber, dtype: int64
#
# listYear
# False    199258
# Name: listYear, dtype: int64
#
# town
# False    199258
# Name: town, dtype: int64
#
# Address
# False    199251
# True          7
# Name: Address, dtype: int64
#
# assessedValue
# False    199258
# Name: assessedValue, dtype: int64
#
# saleAmount
# False    199258
# Name: saleAmount, dtype: int64
#
# salesRatio
# False    199258
# Name: salesRatio, dtype: int64
#
# propertyType
# True     133366
# False     65892
# Name: propertyType, dtype: int64
#
# residentialType
# True     138996
# False     60262
# Name: residentialType, dtype: int64
#
# nonUseCode
# True     154166
# False     45092
# Name: nonUseCode, dtype: int64
#
# assessorRemarks
# True     185733
# False     13525
# Name: assessorRemarks, dtype: int64
#
# oPMremarks
# True     197488
# False      1770
# Name: oPMremarks, dtype: int64

# %%
df_BienesRaices.dtypes
# Out:
# serialNumber         int64
# listYear             int64
# town                object
# Address             object
# assessedValue      float64
# saleAmount         float64
# salesRatio         float64
# propertyType        object
# residentialType     object
# nonUseCode          object
# assessorRemarks     object
# oPMremarks          object
# dtype: object

# %%
import matplotlib as mpl #Se usa para configurar las graficas.

# %%
#Remueve las lineas de los axis.
mpl.rcParams["axes.spines.bottom"] = True
mpl.rcParams["axes.spines.left"] = False
mpl.rcParams["axes.spines.right"] = False
mpl.rcParams["axes.spines.top"] = False

# %%
dfTemp=df_BienesRaices[['saleAmount','listYear']]
dfTemp.head(8)
# Out:
#    saleAmount  listYear
# 0    430000.0      2020
# 1    179900.0      2020
# 2    890000.0      2020
# 3   1447500.0      2020
# 4   1250000.0      2020
# 5    130000.0      2020
# 6    677500.0      2020
# 7    795000.0      2020

# %%
gf = df_BienesRaices.groupby(['listYear']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('serialNumber', ascending=False)
gf
# Out:
#           serialNumber
# listYear
# 2020             65517
# 2001             59584
# 2002             57827
# 2003             14902
# 2018               122
# 2019               121
# 2004               121
# 2006               120
# 2017               108
# 2005                90
# 2016                89
# 2007                89
# 2009                88
# 2014                86
# 2015                85
# 2012                69
# 2013                65
# 2011                62
# 2010                60
# 2008                53

# %%
ingresos_anuales = df_BienesRaices.groupby("listYear")["saleAmount"].sum()
fig, ax = plt.subplots(1,1, figsize =(15,6.9), dpi=100)


ingresos_anuales.plot(kind='bar', color='skyblue')
plt.title('Ingreso Anual de Propiedades Vendidas',horizontalalignment = 'left',x = 0.001,
             y = 0.94,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             fontname = "Liberation Sans Narrow")
plt.xlabel('Año')
plt.ylabel('Ingreso Anual ($)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.

# %%
ingresos_anuales = df_BienesRaices.groupby("listYear")["saleAmount"].sum()


fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(15, 6.9), dpi=100)

pricemin = ingresos_anuales.min()


ax1.plot(ingresos_anuales.index, ingresos_anuales, lw=2)
ax1.set_ylabel('Ingreso Anual ($)')


ax2.fill_between(ingresos_anuales.index, pricemin, ingresos_anuales, alpha=0.7)
ax2.set_ylabel('Ingreso Anual ($)')

# Configuración del título
title_props = {'horizontalalignment': 'left',
               'x': 0.001,
               'y': 0.98,
               'transform': fig.transFigure,
               'fontsize': 20,
               'fontweight': 'bold',
               'fontfamily': 'serif',
               'fontname': 'Liberation Sans Narrow'}
fig.suptitle('Ingreso Anual de Propiedades Vendidas', **title_props)

# Etiquetas de ejes y título
ax1.set_xlabel('Año')
ax2.set_xlabel('Año')
plt.xticks(rotation=45)

# Ajuste de diseño y mostrar la gráfica
fig.autofmt_xdate()
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.

# %% [markdown]
# <h4 Style='color:#009989'> La respuesta a la pregunta sobre cual es el ingreso anual de propiedades vendidas, desde el 2001 hasta el 2020, demostrado con dos tipos de grafica </h4>

# %%
gf = df_BienesRaices.groupby(['propertyType']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('serialNumber', ascending=False)
gf
# Out:
#                 serialNumber
# propertyType
# Residential            59886
# Vacant Land             3025
# Commercial              1912
# Apartments               472
# Condo                    371
# Industrial               217
# Public Utility             4
# Single Family              2
# Two Family                 2
# Three Family               1

# %%
ingresos_anuales = df_BienesRaices.groupby("propertyType")["serialNumber"].count()
fig, ax = plt.subplots(1,1, figsize =(15,6.9), dpi=100)


ingresos_anuales.plot(kind='bar', color='skyblue')
plt.title('Propiedad con mayor facilidad de venta',horizontalalignment = 'left',x = 0.001,
             y = 0.94,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             fontname = "Liberation Sans Narrow")
plt.xlabel('Tipo de Propiedad')
plt.ylabel('Propiedades vendidas')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.

# %% [markdown]
# <h4 Style='color:#009989'> La respuesta a la pregunta sobre cual es el tipo de propiedad con mayor facilidad de venta es: Residential </h4>

# %%
gf = df_BienesRaices.groupby(['town']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('serialNumber', ascending=False)
gf
# Out:
#             serialNumber
# town
# Stamford            7857
# Bridgeport          5982
# Norwalk             5866
# Danbury             4662
# Hartford            4336
# ...                  ...
# Bozrah                94
# Union                 79
# Canaan                79
# Voluntown             76
# Hartland              48
#
# [169 rows x 1 columns]

# %%
gf = df_BienesRaices.groupby(['town','residentialType']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('serialNumber', ascending=False)
gf
# Out:
#                                serialNumber
# town          residentialType
# Waterbury     Single Family            1311
# Greenwich     Single Family            1303
# Stamford      Single Family            1215
#               Condo                    1110
# West Hartford Single Family            1061
# ...                                     ...
# Seymour       Condo                       1
# Lyme          Condo                       1
# Rocky Hill    Two Family                  1
# Redding       Two Family                  1
# Woodstock     Two Family                  1
#
# [494 rows x 1 columns]

# %%
gf = df_BienesRaices.groupby(['town','residentialType','listYear']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('serialNumber', ascending=False)
gf
# Out:
#                                         serialNumber
# town          residentialType listYear
# Waterbury     Single Family   2020              1311
# Greenwich     Single Family   2020              1303
# Stamford      Single Family   2020              1215
#               Condo           2020              1107
# West Hartford Single Family   2020              1061
# ...                                              ...
# Madison       Two Family      2020                 1
#               Condo           2015                 1
# Lyme          Condo           2020                 1
# Litchfield    Three Family    2020                 1
# Woodstock     Two Family      2020                 1
#
# [747 rows x 1 columns]

# %% [markdown]
# <h4 Style='color:#009989'> La respuesta a la pregunta de cual es el pueblo o ciudad con mas ventas de propiedad es Stamford.
# Pero ademas unos datos particulares son que el pueblo con mas propiedades vendidades del tipo Single Family es Waterbury
# y la mayoria hechas en el año 2020</h4>

# %%
gf = df_BienesRaices.groupby(['saleAmount']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('serialNumber', ascending=False)
gf
# Out:
#               serialNumber
# saleAmount
# 1.500000e+05          1984
# 2.500000e+05          1740
# 2.000000e+05          1731
# 1.250000e+05          1609
# 1.750000e+05          1470
# ...                    ...
# 2.358400e+05             1
# 2.358500e+05             1
# 2.359400e+05             1
# 2.359990e+05             1
# 5.000000e+09             1
#
# [15535 rows x 1 columns]

# %%
tipos_deseados = ["Residential", "Commercial"]
df_filtrado = df_BienesRaices[df_BienesRaices['propertyType'].isin(tipos_deseados)]

# %%
costo_promedio_por_tipo = df_filtrado.groupby('propertyType')['saleAmount'].mean()
plt.figure(figsize=(10, 6))
costo_promedio_por_tipo.plot(kind='bar', color="#88c3b5")
plt.title('Costo Promedio de Tipos de Propiedades')
plt.xlabel('Tipo de Propiedad')
plt.ylabel('Costo Promedio')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <h4 Style='color:#009989'> La respuesta sobre la pregunta de cual es el costo promedio de las propiedades comerciales y residenciales, grafica con barras </h4>

# %%
tipos_deseados = ["Residential", "Commercial"]
df_filtrado = df_BienesRaices[df_BienesRaices['propertyType'].isin(tipos_deseados)]
costo_promedio_por_tipo = df_filtrado.groupby('propertyType')['saleAmount'].mean()
circulo= plt.Circle((0,0), 0.7 , color='white')
plt.figure(figsize=( 15, 6),dpi=80, )
plt.pie(costo_promedio_por_tipo, labels=costo_promedio_por_tipo.index , autopct='%1.1f%%', startangle=25) 
plt.title('Distribución del Costo Promedio por Tipo de Propiedad')
plt.axis('equal')  
plt.legend()
plt.show()

# %% [markdown]
# <h4 Style='color:#009989'> Respuesta a la misma pregunta del costo promedio solo que viendo mucho mas evidente la diferencia de las dos propiedades, graficado en pastel </h4>

# %%
gf = df_BienesRaices.groupby(['residentialType','town']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('serialNumber', ascending=False)
gf
# Out:
#                                serialNumber
# residentialType town
# Single Family   Waterbury              1311
#                 Greenwich              1303
#                 Stamford               1215
# Condo           Stamford               1110
# Single Family   West Hartford          1061
# ...                                     ...
# Two Family      Bethlehem                 1
#                 Bethany                   1
#                 Avon                      1
# Three Family    Wolcott                   1
# Two Family      Woodstock                 1
#
# [494 rows x 1 columns]

# %%
tipos_deseados = ['Single Family']
df_filtrado = df_BienesRaices[df_BienesRaices['residentialType'].isin(tipos_deseados)]
costo_promedio_por_tipo = df_BienesRaices.groupby('residentialType')['saleAmount'].mean()

print(costo_promedio_por_tipo)
# Out:
# residentialType
# Condo            416289.786480
# Four Family      319110.855513
# Single Family    515248.207512
# Three Family     407591.129980
# Two Family       271965.161671
# Name: saleAmount, dtype: float64

# %% [markdown]
# <h4 Style='color:#009989'> La respuesta a la pregunta sobre cual es el tipo de propiedades de residencia que se venden con mayor frecuencia donde y con que costo promedio es: Single family en Waterbury con un costo promedio de 515280.21$ </h4>

# %%
# Calcular el margen de ganancia por propiedad
df_BienesRaices['profitMargin'] = ((df_BienesRaices['saleAmount'] - df_BienesRaices['assessedValue']) / df_BienesRaices['assessedValue']) * 100

# Calcular el margen promedio por tipo de propiedad
margen_promedio_por_tipo = df_BienesRaices.groupby('propertyType')['profitMargin'].mean()

print(margen_promedio_por_tipo)
# Out:
# propertyType
# Apartments               NaN
# Commercial               NaN
# Condo              54.239460
# Industrial        184.396167
# Public Utility     41.624379
# Residential              NaN
# Single Family      40.097341
# Three Family      -75.815033
# Two Family         67.802806
# Vacant Land              NaN
# Name: profitMargin, dtype: float64

# %% [markdown]
# <h4 Style='color:#009989'> La respuesta a la pregunta de cual es el margen promedio de ganancia de cada una de las propiedades vendidas es de 312,34512$ </h4>

# %% [markdown]
# <h1 Style='text-align:center; color:#009989'> Fin Del Proyecto</h1>
